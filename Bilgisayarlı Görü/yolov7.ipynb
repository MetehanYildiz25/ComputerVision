# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! git clone https://github.com/WongKinYiu/yolov7.git
# %cd /content/yolov7
# !pip install -r requirements.txt

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="yzyQc0A9kDxUHzzRKkJh")
project = rf.workspace("b200104015subuedutr").project("teknofest-deneme")
dataset = project.version(1).download("yolov7")

# %%
# %cd /content/yolov7
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 100 --data {dataset.location}/data.yaml --weights "yolov7.pt" --device 0
